# %% [markdown]
# <a href="https://colab.research.google.com/github/priyanka-chaurasiya/Python-Project/blob/main/BMI%20Calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#BMI Calculator

# %%
weight = float(input("Enter you weight in kg : "))
height = float(input("Enter you hright in meters : "))

bmi = weight / (height ** 2)

print("you BMI is : ",round(bmi,2))

if bmi < 18.5:
  print("Category: Underweight")
elif 18.5 <= bmi < 24.9:
  print("Category: Normal weight")
elif 25 <= bmi < 29.9:
  print("Category: Overweight")
else:
  print("Category: Obesity")
# Out:
# Enter you weight in kg : 60
# Enter you hright in meters : 1.322
# you BMI is :  34.33
# Category: Obesity
