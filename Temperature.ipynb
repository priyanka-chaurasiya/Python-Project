# %% [markdown]
# <a href="https://colab.research.google.com/github/priyanka-chaurasiya/Python-Project/blob/main/Temperature.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Temperature Converter
#
# Here are functions to convert temperatures between Celsius and Fahrenheit.

# %%
def celsius_to_fahrenheit(celsius):
    """Converts Celsius to Fahrenheit."""
    return (celsius * 9/5) + 32

def fahrenheit_to_celsius(fahrenheit):
    """Converts Fahrenheit to Celsius."""
    return (fahrenheit - 32) * 5/9
    return (fahrenheit - 32) * 5/9

# %% [markdown]
# ### Demonstration

# %%
# Convert 25 Celsius to Fahrenheit
celsius_temp = 25
fahrenheit_result = celsius_to_fahrenheit(celsius_temp)
print(f"{celsius_temp}°C is equal to {fahrenheit_result}°F")

# Convert 77 Fahrenheit to Celsius
fahrenheit_temp = 77
celsius_result = fahrenheit_to_celsius(fahrenheit_temp)
print(f"{fahrenheit_temp}°F is equal to {celsius_result}°C")
