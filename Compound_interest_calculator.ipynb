# %% [markdown]
# <a href="https://colab.research.google.com/github/priyanka-chaurasiya/Python-Project/blob/main/Compound_interest_calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Compound Interest Calculator

principal = float(input("Enter principal amount: "))
rate = float(input("Enter rate of interest (%): "))
time = float(input("Enter time (in years): "))

amount = principal * (1 + rate / 100) ** time
compound_interest = amount - principal

print("Compound Interest:", round(compound_interest, 2))
print("Total Amount:", round(amount, 2))
# Out:
# Enter principal amount: 10000
# Enter rate of interest (%): 2
# Enter time (in years): 5
# Compound Interest: 1040.81
# Total Amount: 11040.81
